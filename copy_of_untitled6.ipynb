# %% [markdown]
# <a href="https://colab.research.google.com/github/Anugrahmsajeevan/python-graph/blob/main/copy_of_untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x=('a', 'b', 'c', 'd', 'e', 'f')
y=('10', '20', '50', '60' ,'70', '80')

# %%
plt.bar(x,y,width=0.87,color='y')
# Out:
# <BarContainer object of 6 artists>

# %%
plt.barh(x,y, color='g')
# Out:
# <BarContainer object of 6 artists>

# %%
import seaborn as sns

# %%
x=('g','h', 'j', 'o','p','k')
y=('10', '90','70','50','77','23')

# %%
iris=sns.load_dataset("iris")

# %%
sns.lineplot(data=iris,x='sepal_length',y='sepal_width',hue="species")
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(data=iris,x='sepal_length',y='sepal_width',hue="species")
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.jointplot(data=iris,x='sepal_length',y='sepal_width',hue="species")

# %%
sns.pairplot(data=iris)

# %%
sns.boxplot(data=iris)
# Out:
# <Axes: >
